# %% [markdown]
# <a href="https://colab.research.google.com/github/AiswaryaSgi/Machine-Learning-Algorithm/blob/main/cardtransdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
import graphviz

# %%
df=pd.read_csv("card_trans.csv")

# %%
df.head()
# Out:
#    distance_from_home  distance_from_last_transaction  \
# 0           57.877857                        0.311140
# 1           10.829943                        0.175592
# 2            5.091079                        0.805153
# 3            2.247564                        5.600044
# 4           44.190936                        0.566486
#
#    ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 0                        1.945940                1          1
# 1                        1.294219                1          0
# 2                        0.427715                1          0
# 3                        0.362663                1          1
# 4                        2.222767                1          1
#
#    used_pin_number  online_order  fraud
# 0                0             0      0
# 1                0             0      0
# 2                0             1      0
# 3                0             1      0
# 4                0             1      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   distance_from_home              9999 non-null   float64
#  1   distance_from_last_transaction  9999 non-null   float64
#  2   ratio_to_median_purchase_price  9999 non-null   float64
#  3   repeat_retailer                 9999 non-null   int64
#  4   used_chip                       9999 non-null   int64
#  5   used_pin_number                 9999 non-null   int64
#  6   online_order                    9999 non-null   int64
#  7   fraud                           9999 non-null   int64
# dtypes: float64(3), int64(5)
# memory usage: 625.1 KB

# %%
df.describe()
# Out:
#        distance_from_home  distance_from_last_transaction  \
# count         9999.000000                     9999.000000
# mean            26.377253                        4.807546
# std             58.813512                       22.261194
# min              0.049270                        0.000930
# 25%              3.810070                        0.305211
# 50%             10.027137                        1.006690
# 75%             25.868282                        3.313808
# max           2033.498174                      990.070315
#
#        ratio_to_median_purchase_price  repeat_retailer    used_chip  \
# count                     9999.000000      9999.000000  9999.000000
# mean                         1.824213         0.879088     0.350735
# std                          2.762572         0.326041     0.477224
# min                          0.011373         0.000000     0.000000
# 25%                          0.489014         1.000000     0.000000
# ...

# %%
df.isnull()
# Out:
#       distance_from_home  distance_from_last_transaction  \
# 0                  False                           False
# 1                  False                           False
# 2                  False                           False
# 3                  False                           False
# 4                  False                           False
# ...                  ...                             ...
# 9994               False                           False
# 9995               False                           False
# 9996               False                           False
# 9997               False                           False
# 9998               False                           False
#
#       ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 0                              False            False      False
# 1                              False            False      False
# 2                              False            False      False
# ...

# %%
df.isnull().sum()
# Out:
# distance_from_home                0
# distance_from_last_transaction    0
# ratio_to_median_purchase_price    0
# repeat_retailer                   0
# used_chip                         0
# used_pin_number                   0
# online_order                      0
# fraud                             0
# dtype: int64

# %%
df.shape
# Out:
# (9999, 8)

# %%
df.tail()
# Out:
#       distance_from_home  distance_from_last_transaction  \
# 9994            7.891519                        0.142338
# 9995            4.225100                        2.678220
# 9996            3.614858                        0.431593
# 9997           10.131863                       10.262508
# 9998           16.306236                        0.014054
#
#       ratio_to_median_purchase_price  repeat_retailer  used_chip  \
# 9994                        0.380634                1          0
# 9995                        0.556858                1          0
# 9996                        0.061778                1          0
# 9997                        2.818090                1          0
# 9998                        1.904495                1          0
#
#       used_pin_number  online_order  fraud
# 9994                0             1      0
# 9995                0             1      0
# 9996                0             1      0
# 9997                0             1      0
# ...

# %%
a=df.distance_from_home
b=df.distance_from_last_transaction
c=df.ratio_to_median_purchase_price
d=df.repeat_retailer

# %%
plt.plot(a,b)

# %%
plt.scatter(a,b)

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 9999 artists>

# %%
plt.hist(a)
# Out:
# (array([9.835e+03, 1.310e+02, 1.700e+01, 1.100e+01, 2.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([4.92701040e-02, 2.03394160e+02, 4.06739051e+02, 6.10083941e+02,
#         8.13428832e+02, 1.01677372e+03, 1.22011861e+03, 1.42346350e+03,
#         1.62680839e+03, 1.83015328e+03, 2.03349817e+03]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(b)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f50a0a01580>,
# ...
# ...
#   Text(0.9604802188806861, 0.5361695153017463, ''),
#   Text(0.9604563532786157, 0.5362122652893563, ''),
#   Text(0.9604235556880512, 0.5362710076813039, ''),
#   Text(0.9603749113943606, 0.5363581168997764, ''),
#   Text(0.960331288662301, 0.5364362180317475, ''),
#   Text(0.9602805655680177, 0.53652701273316, ''),
#   Text(0.9602441702933725, 0.5365921481139961, ''),
#   Text(0.9602222918094787, 0.536631298297213, ''),
#   Text(0.9601997027696269, 0.5366717160435422, ''),
#   Text(0.9598816310061087, 0.537240406575169, ''),
#   Text(0.9594986329857863, 0.5379241334039659, ''),
#   Text(0.9589212479242016, 0.5389527254588217, ''),
#   Text(0.9584019792792798, 0.539875583920554, ''),
#   Text(0.958383469477549, 0.539908441712274, ''),
#   Text(0.9583116969248692, 0.5400358243088857, ''),
#   Text(0.9582248212753194, 0.5401899590809536, ''),
#   Text(0.9581859215476713, 0.5402589561940088, ''),
# ...

# %%
plt.polar(a)

# %%
plt.stem(a)
# Out:
# <ipython-input-18-db0979509a5c>:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(a)
# <StemContainer object of 3 artists>

# %%
X=df.drop('fraud',axis=1)
Y=df['fraud']

# %%
plt.figure(figsize=(20,20))
plotnumber=1
for col in X.columns:
  if plotnumber<=8:
    ax=plt.subplot(5,5,plotnumber)
    sns.boxplot(X[col])
    plt.xlabel(col,fontsize=20)
  plotnumber+=1
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.isna().sum()
# Out:
# distance_from_home                0
# distance_from_last_transaction    0
# ratio_to_median_purchase_price    0
# repeat_retailer                   0
# used_chip                         0
# used_pin_number                   0
# online_order                      0
# fraud                             0
# dtype: int64

# %%
import missingno as mn
mn.bar(df)
plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
a=StandardScaler()
X_train=a.fit_transform(X_train)
X_test=a.transform(X_test)

# %%
clf=DecisionTreeClassifier(criterion="entropy",random_state=0)
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
Y_pred=clf.predict(X_test)

# %%
cm=confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[1842,    0],
#        [   2,  156]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.999

# %%
from sklearn.naive_bayes import GaussianNB
clf1=GaussianNB()

# %%
clf1.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
Y_pred=clf1.predict(X_test)

# %%
cm=confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[1811,   31],
#        [  70,   88]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9495
